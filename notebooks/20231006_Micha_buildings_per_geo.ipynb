# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/train_values.csv")

# %%
df.groupby("geo_level_1_id")["building_id"].count().sort_values(
    ascending=False
).plot.bar()
# Out:
# <Axes: xlabel='geo_level_1_id'>

# %%
df.groupby("geo_level_1_id")["building_id"].count().sort_values(ascending=False)
# Out:
# geo_level_1_id
# 6     24381
# 26    22615
# 10    22079
# 17    21813
# 8     19080
# 7     18994
# 20    17216
# 21    14889
# 4     14568
# 27    12532
# 13     9608
# 11     8220
# 3      7540
# 22     6252
# 25     5624
# 16     4332
# 0      4011
# 9      3958
# 12     3194
# 18     3189
# 1      2701
# 5      2690
# 30     2686
# 15     2320
# 14     1714
# 24     1310
# 23     1121
# 2       931
# 29      396
# 19      372
# 28      265
# Name: building_id, dtype: int64

# %%
df.groupby("geo_level_2_id")["building_id"].count().sort_values(
    ascending=False
).plot.bar()
# Out:
# <Axes: xlabel='geo_level_2_id'>

# %%
df.groupby("geo_level_2_id")["building_id"].count().sort_values(ascending=False)
# Out:
# geo_level_2_id
# 39      4038
# 158     2520
# 181     2080
# 1387    2040
# 157     1897
#         ...
# 77         1
# 637        1
# 1123       1
# 688        1
# 665        1
# Name: building_id, Length: 1414, dtype: int64

# %%
df.groupby("geo_level_3_id")["building_id"].count().sort_values(
    ascending=False
).plot.bar()
# Out:
# <Axes: xlabel='geo_level_3_id'>

# %%
df.groupby("geo_level_3_id")["building_id"].count().sort_values(ascending=False)
# Out:
# geo_level_3_id
# 633      651
# 9133     647
# 621      530
# 11246    470
# 2005     466
#         ...
# 7644       1
# 7639       1
# 7634       1
# 7627       1
# 12567      1
# Name: building_id, Length: 11595, dtype: int64

# %%
df.groupby("geo_level_1_id")["building_id"].count().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("geo_level_2_id")["building_id"].count().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("geo_level_3_id")["building_id"].count().plot.box()
# Out:
# <Axes: >

# %%
level_2 = (
    df.groupby("geo_level_2_id")["building_id"].count().sort_values(ascending=False)
)

# %%
print(len(level_2[level_2 == 1]))
print(len(level_2[level_2 == 2]))
print(len(level_2[level_2 == 3]))
# Out:
# 30
# 14
# 18

# %%
len(level_2)
# Out:
# 1414
