# %% [markdown]
# ## features useable w/o encoding:
# * has_superstructure_adobe_mud
# * has_superstructure_mud_mortar_stone
# * has_superstructure_stone_flag
# * has_superstructure_cement_mortar_stone
# * has_superstructure_mud_mortar_brick
# * has_superstructure_cement_mortar_brick
# * has_superstructure_timber
# * has_superstructure_bamboo
# * has_superstructure_rc_non_engineered
# * has_superstructure_rc_engineered
# * has_superstructure_other

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../data/raw/train_values.csv")

# %%
df.drop(df.iloc[:, 0:14], inplace=True, axis=1)

# %%
df.drop(df.iloc[:, 12:], inplace=True, axis=1)

# %% [markdown]
# Steps for EDA:
# 0. Perform a df.head()
# 1. Make sure you understand every feature.
# 2. View df.shape and df.info()
# 3. Look for NA with df.isna().sum()/df.shape[0]
# 4. Do df.describe()
# 5. Create a boxplot for every column.
# 6. Do a heatmap.
# 7. Look for duplicates.
# 8. If classification: Look for imbalanced target variables!

# %%
df.head()
# Out:
#   plan_configuration  has_superstructure_adobe_mud  \
# 0                  d                             1
# 1                  d                             0
# 2                  d                             0
# 3                  d                             0
# 4                  d                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  \
# 0                                    1                              0
# 1                                    1                              0
# 2                                    1                              0
# 3                                    1                              0
# 4                                    0                              0
#
#    has_superstructure_cement_mortar_stone  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# ...

# %%
df.shape
# Out:
# (260601, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   plan_configuration                      260601 non-null  object
#  1   has_superstructure_adobe_mud            260601 non-null  int64
#  2   has_superstructure_mud_mortar_stone     260601 non-null  int64
#  3   has_superstructure_stone_flag           260601 non-null  int64
#  4   has_superstructure_cement_mortar_stone  260601 non-null  int64
#  5   has_superstructure_mud_mortar_brick     260601 non-null  int64
#  6   has_superstructure_cement_mortar_brick  260601 non-null  int64
#  7   has_superstructure_timber               260601 non-null  int64
#  8   has_superstructure_bamboo               260601 non-null  int64
#  9   has_superstructure_rc_non_engineered    260601 non-null  int64
# ...

# %%
df.isna().sum()/df.shape[0]
# Out:
# plan_configuration                        0.0
# has_superstructure_adobe_mud              0.0
# has_superstructure_mud_mortar_stone       0.0
# has_superstructure_stone_flag             0.0
# has_superstructure_cement_mortar_stone    0.0
# has_superstructure_mud_mortar_brick       0.0
# has_superstructure_cement_mortar_brick    0.0
# has_superstructure_timber                 0.0
# has_superstructure_bamboo                 0.0
# has_superstructure_rc_non_engineered      0.0
# has_superstructure_rc_engineered          0.0
# has_superstructure_other                  0.0
# dtype: float64

# %%
df.describe()
# Out:
#        has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# count                 260601.000000                        260601.000000
# mean                       0.088645                             0.761935
# std                        0.284231                             0.425900
# min                        0.000000                             0.000000
# 25%                        0.000000                             1.000000
# 50%                        0.000000                             1.000000
# 75%                        0.000000                             1.000000
# max                        1.000000                             1.000000
#
#        has_superstructure_stone_flag  has_superstructure_cement_mortar_stone  \
# count                  260601.000000                           260601.000000
# mean                        0.034332                                0.018235
# std                         0.182081                                0.133800
# ...

# %%
df_percentage = df.drop('plan_configuration', axis=1)

# %%
cols = df.drop('plan_configuration', axis=1).columns

for i in cols:
    print(i)
    print(df.loc[:,i].sum()/df.shape[0])
# Out:
# has_superstructure_adobe_mud
# 0.08864509345704737
# has_superstructure_mud_mortar_stone
# 0.7619349119918957
# has_superstructure_stone_flag
# 0.03433217831090441
# has_superstructure_cement_mortar_stone
# 0.0182347726984931
# has_superstructure_mud_mortar_brick
# 0.06815399787414476
# has_superstructure_cement_mortar_brick
# 0.07526832207090534
# has_superstructure_timber
# 0.2549875096411756
# has_superstructure_bamboo
# 0.08501118568232663
# has_superstructure_rc_non_engineered
# 0.042590013085137816
# has_superstructure_rc_engineered
# 0.015859494015755888
# has_superstructure_other
# 0.014984593305474653

# %%
df.plan_configuration.value_counts()
# Out:
# plan_configuration
# d    250072
# q      5692
# u      3649
# s       346
# c       325
# a       252
# o       159
# m        46
# n        38
# f        22
# Name: count, dtype: int64
